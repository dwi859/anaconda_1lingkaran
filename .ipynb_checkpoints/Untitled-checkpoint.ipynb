# %%
import matplotlib.pyplot as plt

import numpy as np

theta = np.linspace(0,2 * np.pi, 100)
fig, ax = plt.subplots(1)

r = np.sqrt(20.0)


x1 = r*np.cos(theta)
x2 = r*np.sin(theta)


ax.plot(x1, x2)

plt.xlim(-4.95, 4.95)
plt.ylim(-4.95, 4.95)

plt.show()
